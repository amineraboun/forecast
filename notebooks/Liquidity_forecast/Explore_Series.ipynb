# %%
import pandas as pd
from forecast_combine.utils.explore import analyse_series

# %%
CIC = pd.read_excel('../data/CIC.xlsx', parse_dates=['date'], index_col='date').squeeze()
NFA = pd.read_excel('../data/NFA.xlsx', parse_dates=['date'], index_col='date').squeeze()
SAB = pd.read_excel('../data/SAB.xlsx', parse_dates=['date'], index_col='date').squeeze()

# %%
analyse_series(CIC, series_name='CIC', period=260, acf_lags=40)
# Out:
# Results of Dickey-Fuller Test:
# ADF Statistic: -1.295511
# p-value: 0.631223
# Critical Values:
# 	1%: -3.437
# 	5%: -2.864
# 	10%: -2.568
# Is the series stationary? No

# %%
analyse_series(NFA, series_name='NFA', period=260, acf_lags=40)
# Out:
# Results of Dickey-Fuller Test:
# ADF Statistic: -1.595660
# p-value: 0.485773
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568
# Is the series stationary? No

# %%
analyse_series(SAB, series_name='SAB', period=260, acf_lags=40)
# Out:
# Results of Dickey-Fuller Test:
# ADF Statistic: -2.541543
# p-value: 0.105691
# Critical Values:
# 	1%: -3.437
# 	5%: -2.864
# 	10%: -2.568
# Is the series stationary? No

# %%
analyse_series(SAB+CIC-NFA, series_name='Total_AF', period=260, acf_lags=40)
# Out:
# Results of Dickey-Fuller Test:
# ADF Statistic: -2.374488
# p-value: 0.149067
# Critical Values:
# 	1%: -3.437
# 	5%: -2.864
# 	10%: -2.568
# Is the series stationary? No
